# %%
import numpy as np
from utils import Util
from rbm import RBM
from IPython.display import display as d

# %%
util = Util()
dir = 'etl/'
rows = 5000
ratings, attractions = util.read_data(dir)
ratings = util.clean_subset(ratings,rows)
num_vis = ratings.attraction_id.nunique()
free_energy = True
rbm_att, train = util.preprocess(ratings)
valid = None
if free_energy:
    train, valid = util.split_data(train)
H = 128
user = 1
alpha = 0.01
rbm = RBM(alpha, H, num_vis)
epochs = 20
batch_size = 8

v = True
# Out:
# Reading the data
# Extracting num_rows from ratings
# Preprocessing the dataset
# Free energy required, dividing into train and validation sets
# Total size of the data is: 661
# Size of the training data is: 495
# Size of the validation data is: 166

# %%
filename = "e"+str(epochs)+"_r"+str(rows)+"_lr"+str(alpha)+"_hu"+str(H)+"_bs"+str(batch_size)
reco, prv_w, prv_vb, prv_hb = rbm.training(train, valid, user, epochs, batch_size, free_energy, v, filename)
reco_l, prv_w_l, prv_vb_l, prv_hb_l = rbm.load_predict(filename, train, user)
# Out:
# Running NumPy-based RBM session
# Training RBM with 20 epochs and batch size: 8
# Starting the training process
# Error after 1 epochs is: 0.2265510857105255
# Error after 2 epochs is: 0.1157476156949997
# Error after 3 epochs is: 0.05755586922168732
# Error after 4 epochs is: 0.03528023883700371
# Error after 5 epochs is: 0.026995288208127022
# Error after 6 epochs is: 0.022625034675002098
# Error after 7 epochs is: 0.020718242973089218
# Error after 8 epochs is: 0.01953873224556446
# Error after 9 epochs is: 0.018286917358636856
# Error after 10 epochs is: 0.017253421247005463
# Error after 11 epochs is: 0.017536485567688942
# Error after 12 epochs is: 0.017207585275173187
# Error after 13 epochs is: 0.01706865429878235
# Error after 14 epochs is: 0.016967996954917908
# Error after 15 epochs is: 0.01680118218064308
# Error after 16 epochs is: 0.016655633226037025
# Error after 17 epochs is: 0.016287509351968765
# Error after 18 epochs is: 0.016042247414588928
# Error after 19 epochs is: 0.016217568889260292
# Error after 20 epochs is: 0.01632058620452881
# Exporting free energy plot
# Exporting errors vs epochs plot
# Model restored from e20_r5000_lr0.01_hu128_bs8

# %%
if np.all(prv_w == prv_w_l) and np.all(prv_vb == prv_vb_l) and np.all(prv_hb == prv_hb_l):
    print ("Model saved and loaded successfully")
# Out:
# Model saved and loaded successfully

# %%
unseen, seen = rbm.calculate_scores(ratings, attractions, reco_l, user, rbm_att)
rbm.export(unseen, seen, 'recommendations/'+filename, str(user))
# Out:
#    attraction_id  Recommendation Score
# 0              0              0.008149
# 1              1              0.004023
# 2              2              0.010142
# 3              3              0.002336
# 4              4              0.021463
